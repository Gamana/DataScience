# %% [markdown]
# # 60 Practice Questions: NumPy, Pandas & SQL
# ## Data Analysis & Cleaning on `studentsample.csv`
#
# **Dataset:** `studentsample.csv` — 20 student records, 10 columns
# **Columns:** `student_id`, `name`, `age`, `gender`, `major`, `gpa`, `attendance_pct`, `city`, `enrollment_year`, `scholarship`
#
# **Setup (Pandas / NumPy):**
# ```python
# import pandas as pd
# import numpy as np
#
# df = pd.read_csv("studentsample.csv")
# ```
#
# **Setup (SQL — SQLite example):**
# ```python
# import sqlite3
#
# conn = sqlite3.connect("students.db")
# df.to_sql("students", conn, index=False, if_exists="replace")
# ```

# %% [markdown]
# ### Setup — run this cell first

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("studentsample.csv")
df.head()

# %% [markdown]
# ### SQL Setup — run before Sections F & G

# %%
import sqlite3

conn = sqlite3.connect("students.db")
df.to_sql("students", conn, index=False, if_exists="replace")
print("Table 'students' created.")

# %% [markdown]
# ## Section A: Pandas — Loading & Inspection (Questions 1–10)

# %% [markdown]
# **Question 1.** Load `studentsample.csv` into a DataFrame named `df`. Display the first 5 rows.

# %%
# Write your code here

# %% [markdown]
# **Question 2.** How many rows and columns does the dataset have? Use `.shape`.

# %%
# Write your code here

# %% [markdown]
# **Question 3.** Display a summary of column data types, non-null counts, and memory usage using `.info()`.

# %%
# Write your code here

# %% [markdown]
# **Question 4.** Show descriptive statistics for all numeric columns using `.describe()`.

# %%
# Write your code here

# %% [markdown]
# **Question 5.** List all column names. How many are categorical vs numeric?

# %%
# Write your code here

# %% [markdown]
# **Question 6.** Display only the `name`, `major`, and `gpa` columns for all students.

# %%
# Write your code here

# %% [markdown]
# **Question 7.** Select rows 5 through 10 (inclusive) using `.iloc`.

# %%
# Write your code here

# %% [markdown]
# **Question 8.** Filter and display students whose `gpa` is greater than 3.5.

# %%
# Write your code here

# %% [markdown]
# **Question 9.** Find all female students (`gender == 'F'`) enrolled in 2023.

# %%
# Write your code here

# %% [markdown]
# **Question 10.** Use `.value_counts()` to count how many students belong to each `major`.
#
# ---

# %%
# Write your code here

# %% [markdown]
# ## Section B: Pandas — Missing Data Detection & Handling (Questions 11–20)

# %% [markdown]
# **Question 11.** Count the total number of missing values in the entire DataFrame using `.isnull().sum().sum()`.

# %%
# Write your code here

# %% [markdown]
# **Question 12.** Show the count of missing values per column. Which column has the most nulls?

# %%
# Write your code here

# %% [markdown]
# **Question 13.** Display all rows where `age` is missing.

# %%
# Write your code here

# %% [markdown]
# **Question 14.** Display all rows that have **at least one** missing value in any column.

# %%
# Write your code here

# %% [markdown]
# **Question 15.** Display all rows where `gpa` **and** `attendance_pct` are both missing.

# %%
# Write your code here

# %% [markdown]
# **Question 16.** What percentage of values are missing in each column? (Hint: `.isnull().mean() * 100`)

# %%
# Write your code here

# %% [markdown]
# **Question 17.** Drop all rows that contain any missing value. How many rows remain?

# %%
# Write your code here

# %% [markdown]
# **Question 18.** Drop only the rows where `student_id` or `name` is missing (should be 0 rows dropped). Then drop rows where `gpa` is missing. How many rows remain?

# %%
# Write your code here

# %% [markdown]
# **Question 19.** Fill missing `age` values with the median age of the dataset.

# %%
# Write your code here

# %% [markdown]
# **Question 20.** Fill missing `scholarship` values with the mode (most frequent value). Fill missing `major` with the string `"Undeclared"`.
#
# ---

# %%
# Write your code here

# %% [markdown]
# ## Section C: Pandas — Cleaning & Transformation (Questions 21–28)

# %% [markdown]
# **Question 21.** Convert the `gpa` column to `float` type explicitly using `.astype()`.

# %%
# Write your code here

# %% [markdown]
# **Question 22.** Create a new column `full_info` by combining `name` and `major` as: `"Alice Johnson - Computer Science"`.

# %%
# Write your code here

# %% [markdown]
# **Question 23.** Extract the first name from the `name` column into a new column `first_name`. (Hint: `.str.split().str[0]`)

# %%
# Write your code here

# %% [markdown]
# **Question 24.** Standardize the `city` column by stripping any leading/trailing whitespace and converting to title case.

# %%
# Write your code here

# %% [markdown]
# **Question 25.** Create a column `gpa_category` with values:
#     - `"High"` if gpa ≥ 3.5
#     - `"Medium"` if 3.0 ≤ gpa < 3.5
#     - `"Low"` if gpa < 3.0
#     - `"Unknown"` if gpa is missing

# %%
# Write your code here

# %% [markdown]
# **Question 26.** Rename the column `attendance_pct` to `attendance_percent`.

# %%
# Write your code here

# %% [markdown]
# **Question 27.** Remove duplicate rows (if any). Check for duplicates based on `student_id`.

# %%
# Write your code here

# %% [markdown]
# **Question 28.** Sort the DataFrame by `gpa` in descending order, then by `name` alphabetically. Display the top 5 students.
#
# ---

# %%
# Write your code here

# %% [markdown]
# ## Section D: Pandas — Analysis & Aggregation (Questions 29–34)

# %% [markdown]
# **Question 29.** Calculate the average `gpa` for the entire dataset (excluding missing values).

# %%
# Write your code here

# %% [markdown]
# **Question 30.** Find the average `gpa` grouped by `gender`.

# %%
# Write your code here

# %% [markdown]
# **Question 31.** Find the average `gpa` and average `attendance_pct` for each `major`.

# %%
# Write your code here

# %% [markdown]
# **Question 32.** Which city has the highest average `gpa`? Display the city name and the average.

# %%
# Write your code here

# %% [markdown]
# **Question 33.** Count how many students received a scholarship (`scholarship == 'Yes'`) per `enrollment_year`.

# %%
# Write your code here

# %% [markdown]
# **Question 34.** Create a pivot table showing average `gpa` with `gender` as rows and `enrollment_year` as columns.
#
# ---

# %%
# Write your code here

# %% [markdown]
# ## Section E: NumPy — Numerical Operations (Questions 35–42)

# %% [markdown]
# **Question 35.** Convert the `gpa` column to a NumPy array using `.values` or `np.array()`. Compute the mean, median, and standard deviation.

# %%
# Write your code here

# %% [markdown]
# **Question 36.** Using NumPy, find the minimum and maximum `gpa` in the dataset.

# %%
# Write your code here

# %% [markdown]
# **Question 37.** Create a NumPy array of `attendance_pct` values (excluding NaN). Compute the 25th, 50th, and 75th percentiles using `np.percentile()`.

# %%
# Write your code here

# %% [markdown]
# **Question 38.** Use `np.nanmean()` and `np.nanstd()` on the `age` column to compute mean and standard deviation while ignoring missing values.

# %%
# Write your code here

# %% [markdown]
# **Question 39.** Replace all `gpa` values below 3.0 with `np.nan`, then recalculate the mean `gpa`.

# %%
# Write your code here

# %% [markdown]
# **Question 40.** Use `np.where()` to create an array `honors` that is `1` where `gpa >= 3.5` and `0` otherwise (treat NaN as 0).

# %%
# Write your code here

# %% [markdown]
# **Question 41.** Compute the correlation between `gpa` and `attendance_pct` using `np.corrcoef()` on the two columns (after dropping rows where either is NaN).

# %%
# Write your code here

# %% [markdown]
# **Question 42.** Normalize the `gpa` column to a 0–1 scale using NumPy:
#     `(gpa - gpa.min()) / (gpa.max() - gpa.min())`
#     Store the result in a new column `gpa_normalized`.
#
# ---

# %%
# Write your code here

# %% [markdown]
# ## Section F: SQL — Analysis & Cleaning (Questions 43–50)

# %% [markdown]
# **Question 43.** Write a SQL query to select all columns for students with a `gpa` above 3.5.

# %%
# Write your SQL query here
# pd.read_sql(""" ... """, conn)

# %% [markdown]
# **Question 44.** Write a query to count the total number of students in the table.

# %%
# Write your SQL query here
# pd.read_sql(""" ... """, conn)

# %% [markdown]
# **Question 45.** Write a query to find all students with missing `age` (use `IS NULL` or `age = ''` depending on how nulls were imported).

# %%
# Write your SQL query here
# pd.read_sql(""" ... """, conn)

# %% [markdown]
# **Question 46.** Write a query to list each `major` and the number of students in that major (`GROUP BY` + `COUNT`).

# %%
# Write your SQL query here
# pd.read_sql(""" ... """, conn)

# %% [markdown]
# **Question 47.** Write a query to find the average `gpa` and average `attendance_pct` grouped by `gender`.

# %%
# Write your SQL query here
# pd.read_sql(""" ... """, conn)

# %% [markdown]
# **Question 48.** Write a query to select students who have a scholarship (`scholarship = 'Yes'`) **and** attendance above 90%.

# %%
# Write your SQL query here
# pd.read_sql(""" ... """, conn)

# %% [markdown]
# **Question 49.** Write a query to update all missing `major` values to `'Undeclared'`.

# %%
# Write your SQL query here
# Q49: UPDATE ...
# Q50: DELETE ... and SELECT ... LIMIT 5

# %% [markdown]
# **Question 50.** Write a query to delete all rows where both `gpa` and `attendance_pct` are NULL. Then write a second query to select students ranked by `gpa` (highest first) using `ORDER BY gpa DESC LIMIT 5`.
#
# ---

# %%
# Write your SQL query here
# Q49: UPDATE ...
# Q50: DELETE ... and SELECT ... LIMIT 5

# %% [markdown]
# ## Section G: SQL — GROUP BY, HAVING, LIMIT & Stored Procedures (Questions 51–60)

# %% [markdown]
# **Question 51.** Write a query to group students by `city` and show the count of students in each city. Order the results by count descending.

# %%
# Write your SQL query here
# pd.read_sql(""" ... """, conn)

# %% [markdown]
# **Question 52.** Write a query using `GROUP BY` and `HAVING` to list only those `major` values where the **average `gpa` is greater than 3.3**.

# %%
# Write your SQL query here
# pd.read_sql(""" ... """, conn)

# %% [markdown]
# **Question 53.** Write a query to find `enrollment_year` values that have **3 or more students**, showing the year and student count. Use `HAVING COUNT(*) >= 3`.

# %%
# Write your SQL query here
# pd.read_sql(""" ... """, conn)

# %% [markdown]
# **Question 54.** Write a query to return the **top 3 students** with the highest `attendance_pct`. Use `ORDER BY` and `LIMIT`. Exclude rows where `attendance_pct` is NULL.

# %%
# Write your SQL query here
# pd.read_sql(""" ... """, conn)

# %% [markdown]
# **Question 55.** Write a query to find the **top 2 majors** by average `gpa` (highest first). Use `GROUP BY`, `ORDER BY AVG(gpa) DESC`, and `LIMIT 2`.

# %%
# Write your SQL query here
# pd.read_sql(""" ... """, conn)

# %% [markdown]
# **Question 56.** Write a query using `GROUP BY city` and `HAVING` to show only cities where **more than 1 student** is enrolled.

# %%
# Write your SQL query here
# pd.read_sql(""" ... """, conn)

# %% [markdown]
# **Question 57.** Write a query to group by both `gender` and `enrollment_year`, showing the count of students for each combination. Order by `enrollment_year`, then `gender`.

# %%
# Write your SQL query here
# pd.read_sql(""" ... """, conn)

# %% [markdown]
# **Question 58.** Write a query using `GROUP BY major` and `HAVING MAX(gpa) >= 3.8` to list majors that have at least one student with a GPA of 3.8 or higher. Display `major` and `MAX(gpa)`.

# %%
# Write your SQL query here
# pd.read_sql(""" ... """, conn)

# %% [markdown]
# **Question 59.** **Stored Procedure:** Write a MySQL stored procedure named `GetStudentsByMajor` that accepts a parameter `p_major` (VARCHAR) and returns all columns for students matching that major.
#
#     ```sql
#     -- Example call: CALL GetStudentsByMajor('Computer Science');
#     ```

# %% [markdown]
# *Write your MySQL stored procedure below (use a new markdown or raw cell):*

# %%
# Optional: test equivalent logic with pandas/SQLite
# SELECT * FROM students WHERE major = 'Computer Science'

# %% [markdown]
# **Question 60.** **Stored Procedure:** Write a MySQL stored procedure named `CountLowGpaStudents` that accepts a threshold parameter `p_gpa` (DECIMAL) and returns a single value — the count of students whose `gpa` is below that threshold (excluding NULL gpa values).
#
#     ```sql
#     -- Example call: CALL CountLowGpaStudents(3.0);
#     ```
#
# **Bonus (PostgreSQL stored procedure syntax):** Rewrite question 59 as a PostgreSQL function that returns a table of matching students.
#
# ---

# %% [markdown]
# *Write your MySQL stored procedure below (use a new markdown or raw cell):*

# %%
# Optional: test equivalent logic with pandas/SQLite
# SELECT * FROM students WHERE major = 'Computer Science'

# %% [markdown]
# ## Quick Reference: Missing Values in `studentsample.csv`
#
# | Column           | Missing Rows (student_id)     |
# |------------------|-------------------------------|
# | age              | S009, S015                    |
# | major            | S009, S016                    |
# | gpa              | S007, S017                    |
# | attendance_pct   | S008, S017, S018, S019        |
# | city             | S009, S019                    |
# | enrollment_year  | S009, S019                    |
# | scholarship      | S005, S011, S020              |
#
# ---

# %% [markdown]
# ## Suggested Learning Path
#
# 1. **Start with Section A** — get comfortable loading and exploring the data.
# 2. **Section B** — practice detecting and handling nulls (core cleaning skill).
# 3. **Section C** — transform and enrich the dataset.
# 4. **Section D** — aggregate and summarize for insights.
# 5. **Section E** — apply NumPy for numerical analysis.
# 6. **Section F** — express the same logic in SQL.
# 7. **Section G** — advanced SQL with `GROUP BY`, `HAVING`, `LIMIT`, and stored procedures.
#
# ---
#
# *File: `studentsample_practice_questions.md` | Dataset: `studentsample.csv`*

# %% [markdown]
# ---
#
# *Practice workbook: `studentsample_practice_questions.ipynb` | Answers: `studentsample_practice_answers.ipynb` | Dataset: `studentsample.csv`*
